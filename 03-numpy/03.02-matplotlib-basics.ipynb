# %% [markdown]
# # Matplotlib 基础

# %% [markdown]
# 在使用**Numpy**之前，需要了解一些画图的基础。
#
# **Matplotlib**是一个类似**Matlab**的工具包，主页地址为
#
# http://matplotlib.org
#
# 导入 `matplotlib` 和 `numpy`：

# %%
# %pylab
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## plot 二维图

# %% [markdown]
# ```python
# plot(y)
# plot(x, y)
# plot(x, y, format_string)
# ```
#
# 只给定 `y` 值，默认以下标为 `x` 轴：

# %%
# %matplotlib inline
x = linspace(0, 2 * pi, 50)
plot(sin(x))

# %% [markdown]
# 给定 `x` 和 `y` 值：

# %%
plot(x, sin(x))

# %% [markdown]
# 多条数据线：

# %%
plot(x, sin(x),
    x, sin(2 * x))
# Out:
# [<matplotlib.lines.Line2D at 0x1fe762c04a8>,
#  <matplotlib.lines.Line2D at 0x1fe762c0668>]

# %% [markdown]
# 使用字符串，给定线条参数：

# %%
plot(x, sin(x), 'r-^')

# %% [markdown]
# 多线条：

# %%
plot(x, sin(x), 'b-o',
    x, sin(2 * x), 'r-^')
# Out:
# [<matplotlib.lines.Line2D at 0x1fe77365668>,
#  <matplotlib.lines.Line2D at 0x1fe77365860>]

# %% [markdown]
# 更多参数设置，请查阅帮助。事实上，字符串使用的格式与**Matlab**相同。

# %% [markdown]
# ## scatter 散点图

# %% [markdown]
# ```python
# scatter(x, y)
# scatter(x, y, size)
# scatter(x, y, size, color)
# ```
#
# 假设我们想画二维散点图：

# %%
plot(x, sin(x), 'bo')

# %% [markdown]
# 可以使用 `scatter` 达到同样的效果：

# %%
scatter(x, sin(x))

# %% [markdown]
# 事实上，scatter函数与**Matlab**的用法相同，还可以指定它的大小，颜色等参数：

# %%
x = rand(200)
y = rand(200)
size = rand(200) * 30
color = rand(200)
scatter(x, y, size, color)
# 显示颜色条
colorbar()

# %% [markdown]
# ## 多图

# %% [markdown]
# 使用figure()命令产生新的图像：

# %%
t = linspace(0, 2*pi, 50)
x = sin(t)
y = cos(t)
figure()
plot(x)
figure()
plot(y)

# %% [markdown]
# 或者使用 `subplot` 在一幅图中画多幅子图：
#
#     subplot(row, column, index)

# %%
subplot(1, 2, 1)
plot(x)
subplot(1, 2, 2)
plot(y)

# %% [markdown]
# ## 向图中添加数据

# %% [markdown]
# 默认多次 `plot` 会叠加：

# %%
plot(x)
plot(y)

# %% [markdown]
# 可以跟**Matlab**类似用 hold(False)关掉，这样新图会将原图覆盖：

# %%
plot(x)
hold(False)
plot(y)
# 恢复原来设定
hold(True)

# %% [markdown]
# ## 标签

# %% [markdown]
# 可以在 `plot` 中加入 `label` ，使用 `legend` 加上图例：

# %%
plot(x, label='sin')
plot(y, label='cos')
legend()

# %% [markdown]
# 或者直接在 `legend`中加入：

# %%
plot(x)
plot(y)
legend(['sin', 'cos'])

# %% [markdown]
# ## 坐标轴，标题，网格

# %% [markdown]
# 可以设置坐标轴的标签和标题：

# %%
plot(x, sin(x))
xlabel('radians')
# 可以设置字体大小
ylabel('amplitude', fontsize='large')
title('Sin(x)')

# %% [markdown]
# 用 'grid()' 来显示网格：

# %%
plot(x, sin(x))
xlabel('radians')
ylabel('amplitude', fontsize='large')
title('Sin(x)')
grid()

# %% [markdown]
# ## 清除、关闭图像

# %% [markdown]
# 清除已有的图像使用：
#
#     clf()
#
# 关闭当前图像：
#
#     close()
#
# 关闭所有图像：
#
#     close('all')

# %% [markdown]
# ## imshow 显示图片

# %% [markdown]
# 灰度图片可以看成二维数组：

# %%
# 导入lena图片
from scipy.misc import ascent
img = ascent()
img
# Out:
# array([[ 83,  83,  83, ..., 117, 117, 117],
#        [ 82,  82,  83, ..., 117, 117, 117],
#        [ 80,  81,  83, ..., 117, 117, 117],
#        ...,
#        [178, 178, 178, ...,  57,  59,  57],
#        [178, 178, 178, ...,  56,  57,  57],
#        [178, 178, 178, ...,  57,  57,  58]])

# %% [markdown]
# 我们可以用 `imshow()` 来显示图片数据：

# %%
imshow(img,
       # 设置坐标范围
      extent = [-25, 25, -25, 25],
       # 设置colormap
      cmap = cm.bone)
colorbar()

# %% [markdown]
# 更多参数和用法可以参阅帮助。

# %% [markdown]
# 这里 `cm` 表示 `colormap`，可以看它的种类：

# %%
dir(cm)
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'LUTSIZE',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Vega10',
#  'Vega10_r',
#  'Vega20',
#  'Vega20_r',
#  'Vega20b',
#  'Vega20b_r',
#  'Vega20c',
#  'Vega20c_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
#  'YlOrRd',
#  'YlOrRd_r',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_deprecation_datad',
#  '_generate_cmap',
#  '_reverse_cmap_spec',
#  '_reverser',
#  'absolute_import',
#  'afmhot',
#  'afmhot_r',
#  'autumn',
#  'autumn_r',
#  'binary',
#  'binary_r',
#  'bone',
#  'bone_r',
#  'brg',
#  'brg_r',
#  'bwr',
#  'bwr_r',
#  'cbook',
#  'cmap_d',
#  'cmapname',
#  'cmaps_listed',
#  'colors',
#  'cool',
#  'cool_r',
#  'coolwarm',
#  'coolwarm_r',
#  'copper',
#  'copper_r',
#  'cubehelix',
#  'cubehelix_r',
#  'datad',
#  'division',
#  'flag',
#  'flag_r',
#  'get_cmap',
#  'gist_earth',
#  'gist_earth_r',
#  'gist_gray',
#  'gist_gray_r',
#  'gist_heat',
#  'gist_heat_r',
#  'gist_ncar',
#  'gist_ncar_r',
#  'gist_rainbow',
#  'gist_rainbow_r',
#  'gist_stern',
#  'gist_stern_r',
#  'gist_yarg',
#  'gist_yarg_r',
#  'gnuplot',
#  'gnuplot2',
#  'gnuplot2_r',
#  'gnuplot_r',
#  'gray',
#  'gray_r',
#  'hot',
#  'hot_r',
#  'hsv',
#  'hsv_r',
#  'inferno',
#  'inferno_r',
#  'jet',
#  'jet_r',
#  'ma',
#  'magma',
#  'magma_r',
#  'mpl',
#  'nipy_spectral',
#  'nipy_spectral_r',
#  'np',
#  'ocean',
#  'ocean_r',
#  'os',
#  'pink',
#  'pink_r',
#  'plasma',
#  'plasma_r',
#  'print_function',
#  'prism',
#  'prism_r',
#  'rainbow',
#  'rainbow_r',
#  'register_cmap',
#  'revcmap',
#  'seismic',
#  'seismic_r',
#  'six',
#  'spectral',
#  'spectral_r',
#  'spring',
#  'spring_r',
#  'summer',
#  'summer_r',
#  'tab10',
#  'tab10_r',
#  'tab20',
#  'tab20_r',
#  'tab20b',
#  'tab20b_r',
#  'tab20c',
#  'tab20c_r',
#  'terrain',
#  'terrain_r',
#  'unicode_literals',
#  'viridis',
#  'viridis_r',
#  'winter',
#  'winter_r']

# %% [markdown]
# 使用不同的 `colormap` 会有不同的显示效果。

# %%
imshow(img, cmap=cm.RdGy_r)

# %% [markdown]
# ## 从脚本中运行

# %% [markdown]
# 在脚本中使用 `plot` 时，通常图像是不会直接显示的，需要增加 `show()` 选项，只有在遇到 `show()` 命令之后，图像才会显示。

# %% [markdown]
# ## 直方图

# %% [markdown]
# 从高斯分布随机生成1000个点得到的直方图：

# %%
hist(randn(1000))
# Out:
# (array([   7.,   19.,   59.,  151.,  261.,  263.,  167.,   54.,   17.,    2.]),
#  array([-3.45054085, -2.76515851, -2.07977618, -1.39439384, -0.70901151,
#         -0.02362917,  0.66175317,  1.3471355 ,  2.03251784,  2.71790018,
#          3.40328251]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# 更多例子请参考下列网站：
#
# http://matplotlib.org/gallery.html
